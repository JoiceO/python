# %% [markdown]
# Importação

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ###Dataset
# * acoes_pura
# * acoes_subiu
# <br><br>
#
# ###Abas
# * acoes
# * total_acoes
# * ticker
# * chatgpt

# %%
# carregar dataset usando url raw
acoes_pura = 'https://github.com/JoiceO/python/blob/9b7597905c505cab4227d4945f4af405d8238c93/Imers%C3%A3o%20Python%20Do%20Excel%20%C3%A0%20An%C3%A1lise%20de%20Dados/02_acoes%20pura.xlsx?raw=true'

# %%
acoes = pd.read_excel(acoes_pura, sheet_name="Principal")
acoes
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# 0           2.26         15.97      9.18      9.56  319,16 M
# 1         -12.11         50.56      6.66      6.86   32,65 M
# 2           7.64         77.55     40.81     42.34  436,69 M
# 3          -4.89         18.85     51.89     53.17  162,55 M
# 4          -3.66         20.70     36.37     37.32   73,42 M
# ..           ...           ...       ...       ...       ...
# 76        -13.98        -32.72     10.70     11.08   38,19 M
# 77        -23.55        -85.74      8.67      8.95   27,54 M
# 78        -11.57         -2.77     56.04     58.90  624,74 M
# 79        -12.29        -36.83      3.05      3.23  101,46 M
# 80        -34.00        -25.44      5.51      6.02  154,36 M
#
# [81 rows x 11 columns]

# %%
total_acoes = pd.read_excel(acoes_pura, sheet_name="Total_de_acoes")
total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   235665566.00
# 1                      ALOS3   532616595.00
# 2                      ALPA4   176733968.00
# 3                      ABEV3  4394245879.00
# 4                      ARZZ3    62305891.00
# ..                       ...            ...
# 84                     VBBR3  1114412532.00
# 85                     WEGE3  1481593024.00
# 86                     YDUQ3   289347914.00
# 87  Quantidade Teórica Total 96372098181.00
# 88                   Redutor    17047850.79
#
# [89 rows x 2 columns]

# %%
ticker = pd.read_excel(acoes_pura, sheet_name="Ticker")
ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %% [markdown]
# Criação da aba "chatGPT", que com apoio de IA, trouxe
# ```
# nome da empresa,
# segmento,
# idade da empresa,
# faixa etária
# ```

# %%
chatgpt = pd.read_excel(acoes_pura, sheet_name="chatGPT")
chatgpt
# Out:
#             Nome            segmento idade da empresa         faixa etária
# 0        Usiminas         Siderurgia          59 anos  Entre 50 e 100 anos
# 1   CSN Mineração          Mineração           6 anos     Menos de 50 anos
# 2       Petrobras     Petróleo e Gás          69 anos  Entre 50 e 100 anos
# 3          Suzano   Papel e Celulose          97 anos     Mais de 100 anos
# 4    CPFL Energia            Energia         109 anos     Mais de 100 anos
# ..            ...                ...              ...                  ...
# 73    Casas Bahia             Varejo          69 anos  Entre 50 e 100 anos
# 74       Localiza  Aluguel de Carros          48 anos  Entre 50 e 100 anos
# 75            CVC            Turismo          50 anos  Entre 50 e 100 anos
# 76            GOL   Transporte Aéreo          20 anos     Menos de 50 anos
# 77         Gerdau         Siderurgia         120 anos     Mais de 100 anos
#
# [78 rows x 4 columns]

# %%
acoes = acoes[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
acoes
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
#renomeando colunas
acoes = acoes.rename(columns={'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
#calculando a variação percentual
acoes['Var_pct'] = acoes['var_dia_pct'] / 100
acoes['valor_inicial'] = acoes['valor_final'] / (acoes['Var_pct'] + 1)
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
acoes = acoes.merge(total_acoes, left_on='Ativo', right_on='Código', how='left')
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
acoes = acoes.drop(columns=['Código'])
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 7 columns]

# %%
acoes['Variacao_rs'] = (acoes['valor_final'] - acoes['valor_inicial'])*acoes['Qtde. Teórica']
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
#ajustando as colunas para ficarem float com 2 casas decimais
pd.options.display.float_format = '{:.2f}'.format

# %%
#transformando em inteiro
acoes['Qtde. Teórica'] = acoes['Qtde. Teórica'].astype(int)
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
acoes = acoes.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
#identificação das ações que subiram, desceram ou ficaram estáveis no final do dia
acoes['Resultado'] = acoes['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
acoes = acoes.merge(ticker, left_on='Ativo', right_on='Ticker', how='left')
acoes = acoes.drop(columns=['Ticker'])
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
##mesclar colunas de chatgpt para acoes
acoes = pd.concat([acoes, chatgpt], axis=1)
acoes
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado          Nome           segmento  \
# 0     515117391   241889725.43     Subiu       Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu  CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu      Petrobras    Petróleo e Gás
# 3     683452836   722946282.71     Subiu         Suzano  Papel e Celulose
# 4     187732538   138573955.06     Subiu   CPFL Energia           Energia
# ..          ...            ...       ...            ...               ...
# 76    533990587  -143635530.57    Desceu            GOL  Transporte Aéreo
# 77     94843047   -20810240.84    Desceu         Gerdau        Siderurgia
# 78    853202347 -1807432634.46    Desceu            NaN               NaN
# 79    525582771   -73557408.06    Desceu            NaN               NaN
# 80    198184909  -102993202.62    Desceu            NaN               NaN
#
#    idade da empresa         faixa etária
# 0           59 anos  Entre 50 e 100 anos
# 1            6 anos     Menos de 50 anos
# 2           69 anos  Entre 50 e 100 anos
# 3           97 anos     Mais de 100 anos
# 4          109 anos     Mais de 100 anos
# ..              ...                  ...
# 76          20 anos     Menos de 50 anos
# 77         120 anos     Mais de 100 anos
# 78              NaN                  NaN
# 79              NaN                  NaN
# 80              NaN                  NaN
#
# [81 rows x 13 columns]

# %% [markdown]
# #Análise descritiva

# %%
# Calculando o maior valor
maior = acoes['Variacao_rs'].max()

# Calculando o menor valor
menor = acoes['Variacao_rs'].min()

# Calculando a média
media = acoes['Variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = acoes[acoes['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = acoes[acoes['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 165,190,210.48
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.75

# %%
acoes_subiu = acoes[acoes['Resultado'] == 'Subiu']
acoes_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 22  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 23  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 24  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 25  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 26  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 27  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 28  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 29  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 30  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 31  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 32  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 33  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 34  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 35  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 36  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 37  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 38  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 39  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 40  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 41  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 42  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 43  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     Qtd_teorica   Variacao_rs Resultado                 Nome   \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3     683452836  722946282.71     Subiu                Suzano
# 4     187732538  138573955.06     Subiu          CPFL Energia
# 5     800010734  709687498.18     Subiu              PetroRio
# 6    4566445852 3103136291.22     Subiu                  Vale
# 7    4196924316 4762926995.25     Subiu             Multiplan
# 8     268505432  117732680.08     Subiu         Itaú Unibanco
# 9    4801593832 2297591984.33     Subiu             Rede D'Or
# 10   1168230366  453917907.01     Subiu               Braskem
# 11    265877867   69054317.64     Subiu                  Azul
# 12    327593725   65452205.55     Subiu          3R Petroleum
# 13    235665566   94204643.35     Subiu    Equatorial Energia
# 14   1095587251  511671895.45     Subiu  Siderúrgica Nacional
# 15    600865451  143220991.46     Subiu                 YDUQS
# 16    289347914   72295838.99     Subiu              Ultrapar
# 17   1086411192  388705223.96     Subiu                   MRV
# 18    376187582   37525872.38     Subiu                Arezzo
# 19     62305891   41021792.09     Subiu        Banco Bradesco
# 20   5146576868  822148336.41     Subiu               Minerva
# 21    261036182   18214628.10     Subiu   Grupo Pão de Açúcar
# 22    159430826    6340916.22     Subiu                   BRF
# 23   1677525446  233045769.57     Subiu                  Vivo
# 24    423091712  188965307.06     Subiu                  Rumo
# 25   1218352541  229771333.63     Subiu                 Cielo
# 26   1095462329   43657683.38     Subiu                 Dexco
# 27    302768240   18068446.61     Subiu                   TIM
# 28    807896814  103972807.37     Subiu             Bradespar
# 29    251003438   42238249.54     Subiu               Locaweb
# 30    393173139   15598886.65     Subiu        PetroRecôncavo
# 31    275005663   46201006.00     Subiu                Itaúsa
# 32   5372783971  373853994.88     Subiu       Banco do Brasil
# 33   1420949112  546752087.99     Subiu          RaiaDrogasil
# 34   1275798515  202352473.74     Subiu    Metalúrgica Gerdau
# 35    660411219   39045606.94     Subiu                 Cosan
# 36   1168097881  127229653.18     Subiu                   JBS
# 37   1134986472  156573285.43     Subiu        Magazine Luiza
# 38   2867627068   28493619.27     Subiu                Raízen
# 39   1500728902   74019610.05     Subiu                 Copel
# 40   1118525506   65779607.10     Subiu           Grupo Vamos
# 41   1193047233   11571106.42     Subiu               Marfrig
# 42   1679335290   32069789.50     Subiu                 Ambev
# 43    421383330    4131341.16     Subiu         BB Seguridade
#
#                 segmento idade da empresa         faixa etária
# 0             Siderurgia          59 anos  Entre 50 e 100 anos
# 1              Mineração           6 anos     Menos de 50 anos
# 2         Petróleo e Gás          69 anos  Entre 50 e 100 anos
# 3       Papel e Celulose          97 anos     Mais de 100 anos
# 4                Energia         109 anos     Mais de 100 anos
# 5         Petróleo e Gás          10 anos     Menos de 50 anos
# 6              Mineração          79 anos  Entre 50 e 100 anos
# 7       Shopping Centers          49 anos  Entre 50 e 100 anos
# 8                  Banco          13 anos     Menos de 50 anos
# 9                  Saúde          45 anos  Entre 50 e 100 anos
# 10               Química          19 anos     Menos de 50 anos
# 11      Transporte Aéreo          14 anos     Menos de 50 anos
# 12        Petróleo e Gás          12 anos     Menos de 50 anos
# 13               Energia          24 anos     Menos de 50 anos
# 14            Siderurgia          81 anos  Entre 50 e 100 anos
# 15              Educação          53 anos  Entre 50 e 100 anos
# 16          Distribuição          84 anos     Mais de 100 anos
# 17      Construção Civil          42 anos  Entre 50 e 100 anos
# 18              Calçados          49 anos  Entre 50 e 100 anos
# 19                 Banco          78 anos     Mais de 100 anos
# 20             Alimentos          29 anos     Menos de 50 anos
# 21                Varejo          72 anos     Mais de 100 anos
# 22             Alimentos          14 anos     Menos de 50 anos
# 23      Telecomunicações          19 anos     Menos de 50 anos
# 24             Logística           5 anos     Menos de 50 anos
# 25  Serviços Financeiros          22 anos     Menos de 50 anos
# 26               Energia          10 anos     Menos de 50 anos
# 27      Telecomunicações          26 anos     Menos de 50 anos
# 28               Holding          21 anos     Menos de 50 anos
# 29            Tecnologia          23 anos     Menos de 50 anos
# 30        Petróleo e Gás           5 anos     Menos de 50 anos
# 31          Conglomerado          55 anos  Entre 50 e 100 anos
# 32                 Banco         213 anos     Mais de 100 anos
# 33   Varejo/Farmacêutico         118 anos     Mais de 100 anos
# 34            Siderurgia         120 anos     Mais de 100 anos
# 35               Energia          14 anos     Menos de 50 anos
# 36             Alimentos          68 anos  Entre 50 e 100 anos
# 37                Varejo          64 anos  Entre 50 e 100 anos
# 38               Energia          10 anos     Menos de 50 anos
# 39               Energia          67 anos  Entre 50 e 100 anos
# 40            Transporte            1 ano     Menos de 50 anos
# 41             Alimentos          13 anos     Menos de 50 anos
# 42               Bebidas          22 anos     Menos de 50 anos
# 43               Seguros           8 anos     Menos de 50 anos

# %% [markdown]
# ## análise por saldo

# %%
analise_saldo = acoes.groupby('Resultado')['Variacao_rs'].sum().reset_index()
analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 19719227010.14

# %%
fig = px.bar(analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.update_traces(texttemplate='%{text:,.2f}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f9779dd-c76d-4345-b28a-af702b8bdeb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f9779dd-c76d-4345-b28a-af702b8bdeb4")) {                    Plotly.newPlot(                        "3f9779dd-c76d-4345-b28a-af702b8bdeb4",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,19719227010.14191],"textposition":"outside","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,19719227010.14191],"yaxis":"y","type":"bar","texttemplate":"%{text:,.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":1 ...

# %% [markdown]
# ##análise por segmento

# %%
analise_segmento = acoes_subiu.groupby('segmento')['Variacao_rs'].sum().reset_index()
analise_segmento
# Out:
#                 segmento   Variacao_rs
# 0              Alimentos  967290012.23
# 1                  Banco  532608467.05
# 2                Bebidas   32069789.50
# 3               Calçados   37525872.38
# 4           Conglomerado   46201006.00
# 5       Construção Civil  388705223.96
# 6           Distribuição   72295838.99
# 7               Educação  143220991.46
# 8                Energia  417995118.04
# 9                Holding  103972807.37
# 10             Logística  188965307.06
# 11             Mineração 3280652261.52
# 12      Papel e Celulose  722946282.71
# 13        Petróleo e Gás 2930797983.91
# 14               Química  453917907.01
# 15                 Saúde 2297591984.33
# 16               Seguros    4131341.16
# 17  Serviços Financeiros  229771333.63
# 18      Shopping Centers 4762926995.25
# 19            Siderurgia  955914094.62
# 20            Tecnologia   42238249.54
# 21      Telecomunicações  251114216.18
# 22            Transporte   65779607.10
# 23      Transporte Aéreo   69054317.64
# 24                Varejo  174787913.53
# 25   Varejo/Farmacêutico  546752087.99

# %%
fig = px.pie(analise_segmento, names='segmento', values='Variacao_rs', title='Variação Reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="599e4670-5a34-454e-8653-0dec36b67dee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("599e4670-5a34-454e-8653-0dec36b67dee")) {                    Plotly.newPlot(                        "599e4670-5a34-454e-8653-0dec36b67dee",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"segmento=%{label}\u003cbr\u003eVariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimentos","Banco","Bebidas","Cal\u00e7ados","Conglomerado","Constru\u00e7\u00e3o Civil","Distribui\u00e7\u00e3o","Educa\u00e7\u00e3o","Energia","Holding","Log\u00edstica","Minera\u00e7\u00e3o","Papel e Celulose","Petr\u00f3leo e G\u00e1s","Qu\u00edmica","Sa\u00fade","Seguros","Servi\u00e7os Financeiros","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Transporte","Transporte A\u00e9reo","Varejo","Varejo\u002fFarmac\u00eautico"],"legendgroup":"","name":"","showlegend":true,"values":[967290012.2338363,532608467.05297315,32069789.503513202,37525872.37728388,46201005.997378685,388705223.95601785,72295838.98616095,143220991.46267557,417995118.0405614,103972807.36695692,188965307.05662104,3280652261.518723,722946282.7090385,2930797983.906364,453917907.01324,2297591984.325198,4131341.15789051,229771333.63468358,4762926995.24809,955914094.6236221,42238249.53998644,251114216.17632303,65779607.09863909,69054317.63603853,174787913.52611017,546752087.993985],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0. ...

# %% [markdown]
# ##análise por faixa etária

# %%
analise_idade = acoes.groupby('faixa etária')['Variacao_rs'].sum().reset_index()
analise_idade
# Out:
#           faixa etária    Variacao_rs
# 0  Entre 50 e 100 anos 11394753202.27
# 1     Mais de 100 anos  1828351636.76
# 2     Menos de 50 anos  2141285454.93

# %%
fig = px.bar(analise_idade, x='faixa etária', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Categoria de Idade')
fig.update_traces(texttemplate='%{text:,.2f}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee6d87a2-7531-4045-b3fe-1d0bf6e7d9fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee6d87a2-7531-4045-b3fe-1d0bf6e7d9fe")) {                    Plotly.newPlot(                        "ee6d87a2-7531-4045-b3fe-1d0bf6e7d9fe",                        [{"alignmentgroup":"True","hovertemplate":"faixa et\u00e1ria=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[11394753202.268057,1828351636.7558665,2141285454.933718],"textposition":"outside","x":["Entre 50 e 100 anos","Mais de 100 anos","Menos de 50 anos"],"xaxis":"x","y":[11394753202.268057,1828351636.7558665,2141285454.933718],"yaxis":"y","type":"bar","texttemplate":"%{text:,.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"co ...
